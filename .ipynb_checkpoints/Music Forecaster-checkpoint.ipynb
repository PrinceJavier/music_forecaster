# %% [markdown]
# # Music Forecaster
# Prince Javier

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Wav File

# %%
from scipy.io import wavfile
fs, data = wavfile.read('Pachelbel Canon in D major MIDI.wav')

# %%
plt.figure(figsize=(15, 4))
# left channel
plt.plot(data[:, 0], linewidth=0.2)
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.title("Left Channel")
plt.show()

# right channel
plt.figure(figsize=(15, 4))
plt.plot(data[:, 1], linewidth=0.2)
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.title("Right Channel")
plt.show()

# %%
# we just get the left channel
wav = data[:, 0]

# %% [markdown]
# ## Split Wav Data into Distinct Elements

# %%
# First get the "regularity" of the beat
# Let's use Fourier transform

from scipy import fftpack

X = fftpack.fft(wav)
freqs = fftpack.fftfreq(len(wav)) * f_s

fig, ax = plt.subplots()

ax.stem(freqs, np.abs(X))
ax.set_xlabel('Frequency in Hertz [Hz]')
ax.set_ylabel('Frequency Domain (Spectrum) Magnitude')
ax.set_xlim(-f_s / 2, f_s / 2)
ax.set_ylim(-5, 110)

# %% [markdown]
# ## Find Notes In each Element Using Fourier Transform

# %% [markdown]
# ## Convert Into a "Music Sheet"

# %% [markdown]
# ## Train Model to Predict Next Notes
